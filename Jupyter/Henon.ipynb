# %% [markdown]
# We use the powerful package [DynamicalSystems.jl](https://juliadynamics.github.io/DynamicalSystems.jl) package for genereating 1 million points with the Hénon map and show the graphical result.

# %%
using DynamicalSystems
using DynamicalSystemsBase.Systems
using StaticArrays # only necessary when defining a system


he = DynamicalSystemsBase.Systems.henon([0.,0.0]; a = 1.4, b = 0.3)
# Out:
# 2-dimensional discrete dynamical system
#  state:       [0.0, 0.0]
#  rule f:      hoop
#  in-place?    false
#  jacobian:    hoop_jac
#  parameters:  [1.4, 0.3]

# %%
traj = trajectory(he, 100000);

# %%
using GR
shade(traj[:,1],traj[:,2], colormap=-2, xlabel="x", ylabel="y")
# Out:
# GR.SVG(UInt8[0x3c, 0x3f, 0x78, 0x6d, 0x6c, 0x20, 0x76, 0x65, 0x72, 0x73  …  0x67, 0x3e, 0x0a, 0x3c, 0x2f, 0x73, 0x76, 0x67, 0x3e, 0x0a])
